# %%
len('...')
# Out:
# 5647

# %%
len('CAGACCACCACAAGGCCTTTTATGG'), len('GGTTCGTTTTGAGTCTGCTTCGGTT')
# Out:
# (25, 25)

# %%
seq='...'

sk323='CTACTAAATGCCGCGGATTGGTTTCG'
sk360='TGCAGGTTGGATACGCCAATC'

sk323 in seq
# Out:
# True

# %%
len(sk323), len(sk360)
# Out:
# (26, 21)

# %%
sk324='CGAAACCAATCCGCGGCATTTAGTAG'
sk359='GAGTTTTATCGCTTCCATGACGCAG'
len(sk324), len(sk359)
sk324 in seq, sk359 in seq
# Out:
# (False, True)

# %%
len(sk324), len(sk359)
# Out:
# (26, 25)
