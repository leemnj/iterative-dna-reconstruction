# %% [markdown]
# # All-in-one runner
#
# This notebook runs the two notebooks sequentially in separate processes.

# %%
import time
import nbformat
from nbclient import NotebookClient

def run_notebook(path):
    print(f'==> START: {path}')
    start = time.time()
    nb = nbformat.read(path, as_version=4)
    client = NotebookClient(nb, timeout=None)
    total = len(nb.cells)
    with client.setup_kernel():
        for idx, cell in enumerate(nb.cells):
            if cell.cell_type != 'code':
                continue
            print(f'  -> Cell {idx + 1}/{total}')
            client.execute_cell(cell, idx)
    nbformat.write(nb, path)
    elapsed = time.time() - start
    print(f'<== DONE: {path} ({elapsed:.1f}s)')

run_notebook('sequence_generation.ipynb')
run_notebook('embedding_and_visualization.ipynb')
# Out:
# ==> START: sequence_generation.ipynb
#   -> Cell 2/14
#   -> Cell 4/14
#   -> Cell 6/14
#   -> Cell 7/14
#   -> Cell 9/14
#   -> Cell 10/14
#   -> Cell 11/14
#   -> Cell 12/14
#   -> Cell 14/14
# <== DONE: sequence_generation.ipynb (1431.4s)
# ==> START: embedding_and_visualization.ipynb
#   -> Cell 2/26
#   -> Cell 4/26
#   -> Cell 7/26
#   -> Cell 9/26
#   -> Cell 10/26
#   -> Cell 14/26
#   -> Cell 16/26
#   -> Cell 19/26
#   -> Cell 20/26
#   -> Cell 21/26
# ---------------------------------------------------------------------------
# CellExecutionError                        Traceback (most recent call last)
# Cell In[2], line 22
#      19     print(f'<== DONE: {path} ({elapsed:.1f}s)')
#      21 run_notebook('sequence_generation.ipynb')
# ---> 22 run_notebook('embedding_and_visualization.ipynb')
#
# Cell In[2], line 16, in run_notebook(path)
#      14             continue
#      15         print(f'  -> Cell {idx + 1}/{total}')
# ---> 16         client.execute_cell(cell, idx)
#      17 nbformat.write(nb, path)
#      18 elapsed = time.time() - start
#
# File /opt/homebrew/Cellar/micromamba/envs/dna-fm/lib/python3.10/site-packages/jupyter_core/utils/__init__.py:171, in run_sync.<locals>.wrapped(*args, **kwargs)
#     169 if name not in _runner_map:
#     170     _runner_map[name] = _TaskRunner()
# --> 171 return _runner_map[name].run(inner)
#
# File /opt/homebrew/Cellar/micromamba/envs/dna-fm/lib/python3.10/site-packages/jupyter_core/utils/__init__.py:128, in _TaskRunner.run(self, coro)
#     126         self.__runner_thread.start()
#     127 fut = asyncio.run_coroutine_threadsafe(coro, self.__io_loop)
# --> 128 return fut.result(None)
#
# File /opt/homebrew/Cellar/micromamba/envs/dna-fm/lib/python3.10/concurrent/futures/_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File /opt/homebrew/Cellar/micromamba/envs/dna-fm/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File /opt/homebrew/Cellar/micromamba/envs/dna-fm/lib/python3.10/site-packages/nbclient/client.py:1062, in NotebookClient.async_execute_cell(self, cell, cell_index, execution_count, store_history)
#    1058                 new_outputs.insert(i, stdout)
#    1060     cell.outputs = new_outputs
# -> 1062 await self._check_raise_for_error(cell, cell_index, exec_reply)
#    1064 self.nb["cells"][cell_index] = cell
#    1065 return cell
#
# File /opt/homebrew/Cellar/micromamba/envs/dna-fm/lib/python3.10/site-packages/nbclient/client.py:918, in NotebookClient._check_raise_for_error(self, cell, cell_index, exec_reply)
#     914 await run_hook(
#     915     self.on_cell_error, cell=cell, cell_index=cell_index, execute_reply=exec_reply
#     916 )
#     917 if not cell_allows_errors:
# --> 918     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
#
# CellExecutionError: An error occurred while executing the following cell:
# ------------------
# from visualization import _plot_final_similarity_raincloud_on_ax
#
# model_labels = list(all_embeddings.keys())
#
# # ===== 1) Coding vs Non-coding (side-by-side) =====
# n_models = len(model_labels)
# fig = plt.figure(figsize=(6.8 * n_models, 4.6))
# grid = fig.add_gridspec(1, n_models, wspace=0.25)
#
# for idx, model_label in enumerate(model_labels):
#     ax = fig.add_subplot(grid[0, idx])
#     embeddings_dict = all_embeddings.get(model_label, {})
#     palette = {"Coding": "#4C78A8", "Non-coding": "#F58518"}
#     _plot_final_similarity_raincloud_on_ax(
#         ax,
#         embeddings_dict,
#         category_map=gene_type_map,
#         category_label="Gene Type",
#         order=["Coding", "Non-coding"],
#         strategies="sampling_t1.0",
#         model_label=model_label,
#         palette=palette,
#         show_ylabel=(idx == 0),
#     )
#     y_labels = ["Coding", "Non-coding"]
#     ax.set_yticks(range(len(y_labels)))
#     ax.set_yticklabels(y_labels)
# fig.suptitle("Final Similarity by Gene Type", y=1.02)
# plt.show()
#
# # ===== 2) Real vs Pseudogene (side-by-side) =====
# n_models = len(model_labels)
# fig = plt.figure(figsize=(6.8 * n_models, 4.6))
# grid = fig.add_gridspec(1, n_models, wspace=0.25)
#
# for idx, model_label in enumerate(model_labels):
#     ax = fig.add_subplot(grid[0, idx])
#     embeddings_dict = all_embeddings.get(model_label, {})
#     palette = {"Real": "#54A24B", "Pseudogene": "#E45756"}
#     _plot_final_similarity_raincloud_on_ax(
#         ax,
#         embeddings_dict,
#         category_map=gene_status_map,
#         category_label="Gene Status",
#         order=["Real", "Pseudogene"],
#         strategies="sampling_t1.0",
#         model_label=model_label,
#         palette=palette,
#         show_ylabel=(idx == 0),
#         gene_type_map=gene_type_map,
#         type_filter=None,
#     )
#     y_labels = ["Real", "Pseudogene"]
#     ax.set_yticks(range(len(y_labels)))
#     ax.set_yticklabels(y_labels)
# fig.suptitle("Final Similarity by Gene Status", y=1.02)
# plt.show()
#
# # ===== 2) Real vs Pseudogene (side-by-side) =====
# n_models = len(model_labels)
# fig = plt.figure(figsize=(6.8 * n_models, 4.6))
# grid = fig.add_gridspec(1, n_models, wspace=0.25)
#
# for idx, model_label in enumerate(model_labels):
#     ax = fig.add_subplot(grid[0, idx])
#     embeddings_dict = all_embeddings.get(model_label, {})
#     palette = {"Real": "#54A24B", "Pseudogene": "#E45756"}
#     _plot_final_similarity_raincloud_on_ax(
#         ax,
#         embeddings_dict,
#         category_map=gene_status_map,
#         category_label="Gene Status",
#         order=["Real", "Pseudogene"],
#         strategies="sampling_t1.0",
#         model_label=model_label,
#         palette=palette,
#         show_ylabel=(idx == 0),
#         gene_type_map=gene_type_map,
#         type_filter="Non-coding",
#     )
#     y_labels = ["Real", "Pseudogene"]
#     ax.set_yticks(range(len(y_labels)))
#     ax.set_yticklabels(y_labels)
# fig.suptitle("Final Similarity by Gene Status", y=1.02)
# plt.show()
# ------------------
#
#
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 40
#      38 embeddings_dict = all_embeddings.get(model_label, {})
#      39 palette = {"Real": "#54A24B", "Pseudogene": "#E45756"}
# ---> 40 _plot_final_similarity_raincloud_on_ax(
#      41     ax,
#      42     embeddings_dict,
#      43     category_map=gene_status_map,
#      44     category_label="Gene Status",
#      45     order=["Real", "Pseudogene"],
#      46     strategies="sampling_t1.0",
#      47     model_label=model_label,
#      48     palette=palette,
#      49     show_ylabel=(idx == 0),
#      50     gene_type_map=gene_type_map,
#      51     type_filter=None,
#      52 )
#      53 y_labels = ["Real", "Pseudogene"]
#      54 ax.set_yticks(range(len(y_labels)))
#
# File ~/Desktop/01_Projects/iterative reconstruction of DNA sequence/iterative-dna-reconstruction/visualization.py:875, in _plot_final_similarity_raincloud_on_ax(ax, embeddings_dict, category_map, category_label, order, strategies, model_label, palette, show_ylabel, gene_type_map, type_filter)
#     872     palette = {}
#     874 before = len(ax.collections)
# --> 875 sns.violinplot(
#     876     data=df,
#     877     x="FinalSimilarity",
#     878     y="Category",
#     879     hue="Category",
#     880     order=order,
#     881     palette=palette,
#     882     inner=None,
#     883     cut=0,
#     884     linewidth=1.0,
#     885     ax=ax,
#     886     legend=False,
#     887 )
#     888 for artist in ax.collections[before:]:
#     889     artist.set_alpha(0.4)
#
# File /opt/homebrew/Cellar/micromamba/envs/dna-fm/lib/python3.10/site-packages/seaborn/categorical.py:1754, in violinplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, inner, split, width, dodge, gap, linewidth, linecolor, cut, gridsize, bw_method, bw_adjust, density_norm, common_norm, hue_norm, formatter, log_scale, native_scale, legend, scale, scale_hue, bw, inner_kws, ax, **kwargs)
#    1751 palette, hue_order = p._hue_backcompat(color, palette, hue_order)
#    1753 saturation = saturation if fill else 1
# -> 1754 p.map_hue(palette=palette, order=hue_order, norm=hue_norm, saturation=saturation)
#    1755 color = _default_color(
#    1756     ax.fill_between, hue, color,
#    1757     {k: v for k, v in kwargs.items() if k in ["c", "color", "fc", "facecolor"]},
#    1758     saturation=saturation,
#    1759 )
#    1760 linecolor = p._complement_color(linecolor, color, p._hue_map)
#
# File /opt/homebrew/Cellar/micromamba/envs/dna-fm/lib/python3.10/site-packages/seaborn/_base.py:838, in VectorPlotter.map_hue(self, palette, order, norm, saturation)
#     837 def map_hue(self, palette=None, order=None, norm=None, saturation=1):
# --> 838     mapping = HueMapping(self, palette, order, norm, saturation)
#     839     self._hue_map = mapping
#
# File /opt/homebrew/Cellar/micromamba/envs/dna-fm/lib/python3.10/site-packages/seaborn/_base.py:150, in HueMapping.__init__(self, plotter, palette, order, norm, saturation)
#     147 elif map_type == "categorical":
#     149     cmap = norm = None
# --> 150     levels, lookup_table = self.categorical_mapping(
#     151         data, palette, order,
#     152     )
#     154 # --- Option 3: datetime mapping
#     155
#     156 else:
#     157     # TODO this needs actual implementation
#     158     cmap = norm = None
#
# File /opt/homebrew/Cellar/micromamba/envs/dna-fm/lib/python3.10/site-packages/seaborn/_base.py:234, in HueMapping.categorical_mapping(self, data, palette, order)
#     232     if any(missing):
#     233         err = "The palette dictionary is missing keys: {}"
# --> 234         raise ValueError(err.format(missing))
#     236     lookup_table = palette
#     238 else:
#
# ValueError: The palette dictionary is missing keys: {'Pseudo'}
